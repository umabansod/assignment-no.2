# %% [markdown]
# # Task 1.

# %% [markdown]
# 1.1.
# Write a Python Program to implement your own myreduce() function which works exactly like
# Python's built-in function reduce()

# %%
# this is my own myreduce() function
def myreduce(anyfunc,l):
    a=l[0]
    for i in l[1:]:
        a=anyfunc(a,i)
    return a

# %%
#this is for e.g purpose anyfunc which we can use in myreduce funtion
def sumation(a,b):
    return a+b

l=[4,5,6,7,8,9]
myreduce(sumation,l)
# Out:
# 39

# %% [markdown]
# ![1.jpg](attachment:1.jpg)

# %% [markdown]
# 1.2.
# Write a Python program to implement your own myfilter() function which works exactly like
# Python's built-in function filter()

# %%
# this is my own myfilter() function
def myfilter(anyfunc,l):
    a=[]
    for i in l:
        if anyfunc(i):
            a.append(i)
    return a

# %%
# for testing
def even_check(n):
    if n%2 ==0:
        return True
   
l=[4,5,6,7,8,9]
myfilter(even_check,l)
# Out:
# [4, 6, 8]

# %% [markdown]
# ![2.jpg](attachment:2.jpg)

# %% [markdown]
# 2.
# Implement List comprehensions to produce the following lists.
# Write List comprehensions to produce the following Lists
# ['A', 'C', 'A', 'D', 'G', 'I', ’L’, ‘ D’]
# ['x', 'xx', 'xxx', 'xxxx', 'y', 'yy', 'yyy', 'yyyy', 'z', 'zz', 'zzz', 'zzzz']
# ['x', 'y', 'z', 'xx', 'yy', 'zz', 'xx', 'yy', 'zz', 'xxxx', 'yyyy', 'zzzz']
# [[2], [3], [4], [3], [4], [5], [4], [5], [6]]
# [[2, 3, 4, 5], [3, 4, 5, 6], [4, 5, 6, 7], [5, 6, 7, 8]]
# [(1, 1), (2, 1), (3, 1), (1, 2), (2, 2), (3, 2), (1, 3), (2, 3), (3, 3)]

# %%
word ='ACADGILD'
list=[alpha for alpha in word]
list
# Out:
# ['A', 'C', 'A', 'D', 'G', 'I', 'L', 'D']

# %%
word='xyz'
list=[i*n for i in word for n in range(1,5)]
list
# Out:
# ['x', 'xx', 'xxx', 'xxxx', 'y', 'yy', 'yyy', 'yyyy', 'z', 'zz', 'zzz', 'zzzz']

# %%
word='xyz'
list=[i*n for n in range(1,5)for i in word]
list
# Out:
# ['x', 'y', 'z', 'xx', 'yy', 'zz', 'xxx', 'yyy', 'zzz', 'xxxx', 'yyyy', 'zzzz']

# %%
num=[1,2,3]
series=[[i+j] for j in num for i in range(0,3)]
series
# Out:
# [[1], [2], [3], [2], [3], [4], [3], [4], [5]]

# %%
num=[2,3,4,5]
series=[[i+j for j in num] for i in range (0,4)]
series
# Out:
# [[2, 3, 4, 5], [3, 4, 5, 6], [4, 5, 6, 7], [5, 6, 7, 8]]

# %%
list=[1,2,3]
output=[(i,j) for j in list for i in list]
output
# Out:
# [(1, 1), (2, 1), (3, 1), (1, 2), (2, 2), (3, 2), (1, 3), (2, 3), (3, 3)]

# %% [markdown]
# ![3.jpg](attachment:3.jpg)

# %% [markdown]
# 3.
# Implement a function longestWord() that takes a list of words and returns the longest one.

# %%
def longestWord(word_list):
    word_len=[]
    for i in word_list:
        word_len.append((len(i),i))
    word_len.sort()
    return word_len[-1][1]

print(longestWord(['uma','samir','bansod']))
# Out:
# bansod

# %% [markdown]
# ![4.jpg](attachment:4.jpg)

# %% [markdown]
# # Task 2:

# %% [markdown]
# 1.1
# Write a Python Program(with class concepts) to find the area of the triangle using the below
# formula.
# area = (s*(s-a)*(s-b)*(s-c)) ** 0.5
# Function to take the length of the sides of triangle from user should be defined in the parent
# class and function to calculate the area should be defined in subclass

# %%
class Triangle:
    def __init__(self,a,b,c):
        self.a = a
        self.b = b
        self.c = c
    def area(self):
        s=(self.a + self.b + self.c)/2
        return(s*((s-self.a)*(s-self.b)*(s-self.c)))** 0.5
a=int(input('enter first side:'))
b=int(input('enter secound side:'))        
c=int(input('enter third side:'))

r=Triangle(a,b,c)
print('area:',r.area())
# Out:
# enter first side:26
# enter secound side:35
# enter third side:23
# area: 298.95819105687673

# %% [markdown]
# ![5.jpg](attachment:5.jpg)

# %% [markdown]
# 1.2
# Write a function filter_long_words() that takes a list of words and an integer n and returns the list
# of words that are longer than n.

# %%
def filter_long_words(list_of_word,num):
    m=[]
    for i in range(len(list_of_word)):
        if len(list_of_word[i])>num:
            m.append(list_of_word[i])
    return m

print(filter_long_words(['uma','samir','bansod'],3))
# Out:
# ['samir', 'bansod']

# %% [markdown]
# ![6.jpg](attachment:6.jpg)

# %% [markdown]
# 2.1
# Write a Python program using function concept that maps list of words into a list of integers
# representing the lengths of the corresponding words .
# Hint: If a list [ ab,cde,erty] is passed on to the python function output should come as [2,3,4]
# Here 2,3 and 4 are the lengths of the words in the list.

# %%
def convert_into_int(listofword):
    m=[]
    for i in listofword:
        m.append(len(i))
    return m   

convert_into_int(['ab','cde','erty'])
# Out:
# [2, 3, 4]

# %% [markdown]
# ![7.jpg](attachment:7.jpg)

# %% [markdown]
# 2.2
# Write a Python function which takes a character (i.e. a string of length 1) and returns True if it is
# a vowel, False otherwise.

# %%
def is_vowel(char):
    vowel='aeiou'
    if char in vowel:
        return True
    else:
        return False
    
    
print(is_vowel('b'))
print(is_vowel('e'))
# Out:
# False
# True
